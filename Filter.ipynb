# %% [markdown]
# <a href="https://colab.research.google.com/github/hooverpantoja/GitHubRep/blob/master/Filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: read an audio file from a drive location
#!pip install scikit-maad
from maad import sound, util
import numpy as np
import librosa
import matplotlib.pyplot as plt
from google.colab import drive
#drive.mount('/content/drive')



# Replace with the actual path to your audio file on Google Drive
file_path = '/content/drive/MyDrive/Colab Notebooks/s.wav'

s,fs=sound.load(file_path)
plt.plot(s)

N=1024
Sxx_power,tn,fn,ext = sound.spectrogram (s, fs, nperseg=N, noverlap=N//2, mode = 'psd')
Sxx_dB = util.power2dB(Sxx_power)
fig, ax = util.plot2d(Sxx_dB)

# %%
# prompt: filter the loaded signal by using an moving average filter

# Moving average filter
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# Example usage (replace with your desired window size)
window_size = 3
filtered_signal = moving_average(s, window_size)

#Now you can plot or further process filtered_signal
import matplotlib.pyplot as plt
plt.plot(filtered_signal)
plt.title("Filtered Signal")
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()

N=1024
Sxx_power,tn,fn,ext = sound.spectrogram (filtered_signal, fs, nperseg=N, noverlap=N//2, mode = 'psd')
Sxx_dB = util.power2dB(Sxx_power)
fig, ax = util.plot2d(Sxx_dB)
